# %%
import matplotlib.pyplot as plt

plt.bar(["Theoretical", "Experimental"], [1312.5, 880.0])
plt.ylabel("Time (microseconds)")
plt.title("Time to traverse array")
# Out:
# Text(0.5, 1.0, 'Time to traverse array')
